# %% [markdown]
# ### Gráfico de Dispersión: `petal_length` vs `petal_width`

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=df, s=100, alpha=0.8)
plt.title('Relación entre Longitud y Ancho del Pétalo en el Dataset Iris')
plt.xlabel('Longitud del Pétalo (cm)')
plt.ylabel('Ancho del Pétalo (cm)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Especie')
plt.show()

# %% [markdown]
# ### Visualización de la Matriz de Correlación con un Mapa de Calor

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación del Dataset Iris')
plt.show()

# %% [markdown]
# ### Matriz de Correlación para Columnas Numéricas

# %%
# Calcula la matriz de correlación para las columnas numéricas
print("Matriz de correlación:")
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)
# Out:
# Matriz de correlación:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import pandas as pd
import seaborn as sns

# Load the iris dataset
df = sns.load_dataset('iris')

print("First 5 rows of the dataset:")
display(df.head())
# Out:
# First 5 rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Descriptive Statistics for Numerical Columns

# %%
# Display descriptive statistics for numerical columns
print("Descriptive statistics for numerical columns:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Descriptive Statistics for Categorical Columns

# %%
# Display descriptive statistics for categorical columns
print("Descriptive statistics for categorical columns:")
display(df.describe(include='object'))

# Also show value counts for the categorical column to get more detail
print("Value counts for 'species' column:")
display(df['species'].value_counts())
# Out:
# Descriptive statistics for categorical columns:
#        species
# count      150
# unique       3
# top     setosa
# freq        50
# Value counts for 'species' column:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %% [markdown]
# # Task
# Perform an Exploratory Data Analysis (EDA) on the Iris dataset, including checking for missing values, verifying data types, displaying descriptive statistics, visualizing numerical feature distributions (histograms/box plots) and categorical feature counts (count plot for 'species'), analyzing and visualizing the correlation matrix, and visualizing feature relationships using scatter plots, concluding with a summary of key findings.

# %% [markdown]
# ## Load and Initial Inspect Data
#
# ### Subtask:
# Load the Iris dataset into a pandas DataFrame and display its first 5 rows to get an initial overview of the data structure and content.

# %% [markdown]
# ## Check for Missing Values and Data Types
#
# ### Subtask:
# Examine the dataset for any missing values across all columns and verify the data types of each column to ensure data quality and prepare for analysis.

# %% [markdown]
# **Reasoning**:
# First, I will use the `.info()` method to get a concise summary of the DataFrame, including the data types and non-null counts for each column, which helps in identifying potential missing values and verifying data types.

# %%
print("DataFrame Information:")
df.info()
# Out:
# DataFrame Information:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_172/1719689523.py in <cell line: 0>()
#       1 print("DataFrame Information:")
# ----> 2 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Reasoning**:
# The previous code failed because the DataFrame `df` was not defined, indicating that the cell responsible for loading the dataset was not executed. To fix this, I will include the dataset loading step (`df = sns.load_dataset('iris')`) and necessary imports (`import pandas as pd`, `import seaborn as sns`) directly in the current cell. Additionally, I will add `df.isnull().sum()` to explicitly show the count of missing values per column, addressing the second instruction of the subtask.

# %%
import pandas as pd
import seaborn as sns

# Load the iris dataset
df = sns.load_dataset('iris')

print("DataFrame Information:")
df.info()

print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#
# Missing values per column:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Display Descriptive Statistics
#
# ### Subtask:
# Show descriptive statistics for both numerical and categorical columns to understand the central tendency, spread, and distribution of the data.

# %% [markdown]
# **Reasoning**:
# To address all parts of the subtask, I will first display descriptive statistics for numerical columns using `df.describe()`, then for categorical columns using `df.describe(include='object')`, and finally show the value counts for the 'species' column using `df['species'].value_counts()` to understand its distribution.

# %%
print("Descriptive statistics for numerical columns:")
display(df.describe())

print("\nDescriptive statistics for categorical columns:")
display(df.describe(include='object'))

print("\nValue counts for 'species' column:")
display(df['species'].value_counts())
# Out:
# Descriptive statistics for numerical columns:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# Descriptive statistics for categorical columns:
#        species
# count      150
# unique       3
# top     setosa
# freq        50
# Value counts for 'species' column:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## Visualize Numerical Feature Distributions
#
# ### Subtask:
# Create histograms or box plots for each numerical feature (sepal_length, sepal_width, petal_length, petal_width) to visualize their distributions and identify potential outliers or skewness. Ensure plots have appropriate titles and labels.

# %% [markdown]
# **Reasoning**:
# To visualize the distributions of numerical features as histograms, I will import `matplotlib.pyplot` and `seaborn`, create a figure with subplots, and iterate through the numerical columns to generate and display a histogram for each, ensuring proper titles and labels.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Create subplots for histograms
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
axes = axes.flatten() # Flatten the 2x2 array of axes for easy iteration

for i, col in enumerate(numerical_cols):
    sns.histplot(df[col], kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Distribución de {col.replace("_", " ").title()}')
    axes[i].set_xlabel(col.replace("_", " ").title())
    axes[i].set_ylabel('Frecuencia')
    axes[i].grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize Categorical Feature Counts
#
# ### Subtask:
# Generate a count plot for the 'species' column to visualize the frequency of each Iris species, providing insight into the distribution of the target variable. Ensure the plot has a title and labels, and a legend if applicable.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of the categorical 'species' column, I will generate a count plot using `seaborn.countplot` as instructed, adding appropriate titles and labels for clarity.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(x='species', data=df, palette='viridis')
plt.title('Frecuencia de Especies en el Dataset Iris')
plt.xlabel('Especie')
plt.ylabel('Conteo')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# /tmp/ipykernel_172/2517482925.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data=df, palette='viridis')

# %% [markdown]
# **Reasoning**:
# The previous code generated a `FutureWarning` because `palette` was used without assigning a `hue` argument in `sns.countplot`. To fix this and follow best practices for newer seaborn versions, I will assign the 'species' column to both `x` and `hue` and set `legend=False`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(x='species', data=df, hue='species', palette='viridis', legend=False)
plt.title('Frecuencia de Especies en el Dataset Iris')
plt.xlabel('Especie')
plt.ylabel('Conteo')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ## Analyze and Visualize Correlation Matrix
#
# ### Subtask:
# Calculate the correlation matrix for all numerical features to understand the linear relationships between them. Then, visualize this matrix using a heatmap for an intuitive representation of correlations.

# %% [markdown]
# **Reasoning**:
# To analyze and visualize the correlation matrix, I will first calculate the correlation matrix for the numerical features of the DataFrame `df` and store it in `correlation_matrix`. Then, I will print this matrix and use `seaborn.heatmap` to create a visual representation of these correlations, including annotations and a descriptive title, as specified in the instructions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix for the numerical columns
correlation_matrix = df.corr(numeric_only=True)

print("Matriz de correlación:")
display(correlation_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación del Dataset Iris')
plt.show()
# Out:
# Matriz de correlación:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ## Visualize Feature Relationships (Scatter Plot)
#
# ### Subtask:
# Create a scatter plot to visualize the relationship between 'petal_length' and 'petal_width', using 'species' as the hue to differentiate between the different Iris types.

# %% [markdown]
# **Reasoning**:
# To visualize the relationship between 'petal_length' and 'petal_width' separated by species, I will generate a scatter plot using `seaborn.scatterplot`, incorporating all the requested aesthetic and labeling details.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='petal_length', y='petal_width', hue='species', data=df, s=100, alpha=0.8)
plt.title('Relación entre Longitud y Ancho del Pétalo en el Dataset Iris')
plt.xlabel('Longitud del Pétalo (cm)')
plt.ylabel('Ancho del Pétalo (cm)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Especie')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.datasets import load_iris
data = load_iris()

df_pca = pd.DataFrame(data=X_reduced.data, columns=data.feature_names)
df_pca['target'] = data.target

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the key findings and insights obtained from the Exploratory Data Analysis of the Iris dataset, highlighting important observations about feature distributions, relationships, and species characteristics.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Data Integrity:** The Iris dataset, consisting of 150 entries and 5 columns, was found to be complete with **no missing values** across all features. Data types were appropriate: four numerical features (`sepal_length`, `sepal_width`, `petal_length`, `petal_width`) as `float64` and the `species` column as `object`.
# *   **Species Distribution:** The dataset is perfectly balanced, with **50 instances for each of the three Iris species**: 'setosa', 'versicolor', and 'virginica'.
# *   **Numerical Feature Distributions:**
#     *   `sepal_length`: Ranges from 4.3 to 7.9 cm (mean \~5.84 cm) and shows a relatively normal, possibly bimodal, distribution.
#     *   `sepal_width`: Ranges from 2.0 to 4.4 cm (mean \~3.06 cm) and appears normally distributed.
#     *   `petal_length`: Ranges from 1.0 to 6.9 cm (mean \~3.76 cm) and exhibits a clearly multimodal distribution, suggesting distinct groupings.
#     *   `petal_width`: Ranges from 0.1 to 2.5 cm (mean \~1.20 cm) and also shows a multimodal distribution.
# *   **Feature Correlations:**
#     *   Strong positive correlations were observed between petal dimensions: `petal_length` and `petal_width` (0.96).
#     *   Significant positive correlations also exist between `sepal_length` and `petal_length` (0.87), and `sepal_length` and `petal_width` (0.82).
#     *   `sepal_width` shows weak negative correlations with other features, notably with `petal_length` (-0.43) and `petal_width` (-0.37).
# *   **Species Separation by Petal Dimensions:** Scatter plots revealed that Iris species are distinctly separable based on `petal_length` and `petal_width`. 'Setosa' forms a very separate cluster with smaller petal dimensions, while 'versicolor' and 'virginica' show some overlap but are generally distinguishable, with 'virginica' having larger petal dimensions.
#
# ### Insights or Next Steps
#
# *   The distinct clustering of species by petal dimensions suggests that `petal_length` and `petal_width` are highly influential features for species classification and could serve as strong predictors.
# *   Given the strong correlations among certain features (e.g., `petal_length` and `petal_width`), further analysis might involve feature selection or dimensionality reduction techniques to optimize model performance, although the number of features is already small.
